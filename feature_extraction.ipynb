# %%
import pandas as pd
import pickle
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))
# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121      2497    Sri Lanka    Australia  19.3     1                0  Colombo
# 122      2497    Sri Lanka    Australia  19.4     0                0  Colombo
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124      2497    Sri Lanka    Australia  19.6     2                0  Colombo
# 125      2497    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [96713 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8549
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Sharjah Cricket Stadium                     127
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [96713 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
list(eligible_cities)
# Out:
# ['Colombo',
#  'Dubai',
#  'Johannesburg',
#  'Mirpur',
#  'Auckland',
#  'Sydney',
#  'Dhaka',
#  'Cape Town',
#  'Lahore',
#  'London',
#  'Melbourne',
#  'Pallekele',
#  'Durban',
#  'Wellington',
#  'Barbados',
#  'Abu Dhabi',
#  'Centurion',
#  'Lauderhill',
#  'Christchurch',
#  'Southampton',
#  'Hamilton',
#  'Gros Islet',
#  'Manchester',
#  'Nottingham',
#  'St Lucia',
#  'Karachi',
#  'Mount Maunganui',
#  'Kolkata',
#  'Cardiff',
#  'Bridgetown',
#  'Adelaide',
#  'Mumbai',
#  'Tarouba',
#  'Birmingham',
#  'Brisbane',
#  "St George's",
#  'Kandy',
#  'Sharjah',
#  'Chittagong',
#  'Delhi',
#  'Ahmedabad',
#  'Providence',
#  'Chandigarh',
#  'Kingston',
#  'Perth',
#  'Napier',
#  'Nagpur',
#  'Rajkot',
#  'Bangalore',
#  'Sylhet',
#  'Dambulla',
#  'Hobart',
#  'Trinidad']

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [82013 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [82013 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [82013 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [82013 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121      2497    Sri Lanka    Australia  19.3     1                0
# 122      2497    Sri Lanka    Australia  19.4     0                0
# 123      2497    Sri Lanka    Australia  19.5     0      DM de Silva
# 124      2497    Sri Lanka    Australia  19.6     2                0
# 125      2497    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [82013 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121      2497    Sri Lanka    Australia  19.3     1                 8
# 122      2497    Sri Lanka    Australia  19.4     0                 8
# 123      2497    Sri Lanka    Australia  19.5     0                 9
# 124      2497    Sri Lanka    Australia  19.6     2                 9
# 125      2497    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [82013 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121      2497    Sri Lanka    Australia  19.3     1                 8
# 122      2497    Sri Lanka    Australia  19.4     0                 8
# 123      2497    Sri Lanka    Australia  19.5     0                 9
# 124      2497    Sri Lanka    Australia  19.6     2                 9
# 125      2497    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [82013 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five']]
# Out:
#     batting_team bowling_team       city  current_score  balls_left  \
# 0      Australia    Sri Lanka  Melbourne              0         119
# 1      Australia    Sri Lanka  Melbourne              0         118
# 2      Australia    Sri Lanka  Melbourne              1         117
# 3      Australia    Sri Lanka  Melbourne              3         116
# 4      Australia    Sri Lanka  Melbourne              3         115
# ..           ...          ...        ...            ...         ...
# 121    Sri Lanka    Australia    Colombo            125           3
# 122    Sri Lanka    Australia    Colombo            125           2
# 123    Sri Lanka    Australia    Colombo            125           1
# 124    Sri Lanka    Australia    Colombo            127           0
# 125    Sri Lanka    Australia    Colombo            128           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [82013 rows x 8 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team         city  current_score  balls_left  \
# 54975      Pakistan   Bangladesh     St Lucia             70          68
# 77239       England     Pakistan      Sharjah             57          72
# 20184         India    Sri Lanka      Colombo            129           5
# 80028  South Africa  West Indies       Nagpur             65          55
# 37062   West Indies      England  St George's             90          40
# ...             ...          ...          ...            ...         ...
# 54917     Australia     Pakistan    Melbourne            119          13
# 9972       Pakistan    Australia        Dubai            149           1
# 8189      Australia        India    Melbourne             74          42
# 66941       England  New Zealand     Auckland             64          80
# 13701   West Indies        India   Providence            110          21
#
#        wickets_left       crr  last_five  runs_x
# 54975            10  8.076923       40.0     172
# 77239             7  7.125000       36.0     154
# 20184             6  6.730435       37.0     132
# 80028             5  6.000000       27.0     122
# 37062             6  6.750000       36.0     176
# ...             ...       ...        ...     ...
# 54917             1  6.672897       33.0     127
# 9972              5  7.512605       39.0     150
# 8189              5  5.692308       26.0     132
# 66941             9  9.600000       45.0     214
# 13701             5  6.666667       38.0     146
#
# [62481 rows x 9 columns]

# %%
final_df.sample(2)
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 16522     Australia  New Zealand  Wellington            146          29
# 7828   South Africa    Sri Lanka   Centurion            110          42
#
#        wickets_left       crr  last_five  runs_x
# 16522             8  9.626374       55.0     208
# 7828              9  8.461538       54.0     180

# %% [markdown]
# ##### spliting data to train and test

# %%
# X = final_df.drop(columns=['runs_x'])
# y = final_df['runs_x']
from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# Splitting dataset
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 44624   New Zealand     Sri Lanka    Dambulla             91          17
# 7825   South Africa     Sri Lanka   Centurion            107          45
# 37838   West Indies         India     Tarouba            134           9
# 68151   West Indies    Bangladesh      Mirpur             86          55
# 4596          India   New Zealand       Delhi             77          63
# ...             ...           ...         ...            ...         ...
# 10304      Pakistan   New Zealand       Dubai            101          35
# 46908    Bangladesh  South Africa   Cape Town             74          80
# 41860      Pakistan     Australia      Hobart             92          40
# 40668         India     Australia  Gros Islet            116          59
# 46744         India      Pakistan      Durban            141           0
#
#        wickets_left        crr  last_five
# 44624             3   5.300971       30.0
# 7825              9   8.560000       59.0
# 37838             5   7.243243       39.0
# 68151             8   7.938462       43.0
# 4596             10   8.105263       39.0
# ...             ...        ...        ...
# 10304             9   7.129412       41.0
# 46908             6  11.100000       60.0
# 41860             4   6.900000       25.0
# 40668             8  11.409836       63.0
# 46744             1   7.050000       44.0
#
# [49984 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
# Preprocessing transformer
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %% [markdown]
# ##### Random Forest Model Pipeline

# %%
rf_pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', RandomForestRegressor(n_estimators=500, max_depth=25, max_features="sqrt", n_jobs=-1, random_state=1))
])

# %% [markdown]
# ##### XGBoost Model Pipeline

# %%
xgb_pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=12, random_state=1))
])

# %%
# Train both models
rf_pipe.fit(X_train, y_train)
xgb_pipe.fit(X_train, y_train)

# Predictions for test data
rf_pred = rf_pipe.predict(X_test)
xgb_pred = xgb_pipe.predict(X_test)

print("\n🌲 Random Forest Performance:")
print("R² Score:", r2_score(y_test, rf_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, rf_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, rf_pred))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, rf_pred)))

print("\n🚀 XGBoost Performance:")
print("R² Score:", r2_score(y_test, xgb_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, xgb_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, xgb_pred))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, xgb_pred)))
# Out:
# 🌲 Random Forest Performance:
# R² Score: 0.9386917368480892
# Mean Absolute Error (MAE): 5.562970558466666
# Mean Squared Error (MSE): 68.5825460804624
# Root Mean Squared Error (RMSE): 8.281457968284473
#
# 🚀 XGBoost Performance:
# R² Score: 0.9866967797279358
# Mean Absolute Error (MAE): 1.8769241571426392
# Mean Squared Error (MSE): 14.881682395935059
# Root Mean Squared Error (RMSE): 3.857678368648047

# %%
# Save both models
pickle.dump(rf_pipe, open('rf_pipe.pkl', 'wb'))
pickle.dump(xgb_pipe, open('xgb_pipe.pkl', 'wb'))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import xgboost
xgboost.__version__
# Out:
# '2.1.4'
